# %% [markdown]
# ### Abayomi Queen
# Set and Tuples Assignmnet
# 27/10/25

# %% [markdown]
# ## Nested and Mixed Tuples

# %%
#  Accessing elements within nested tuples and employing diverse data types
student = ("Sarah", 24, ("Math", "Biology", "Chemistry"))

# %%
# Presenting students name
name, age, subject= student

# %%
# students name
name
# Out:
# 'Sarah'

# %%
# Academic subject
subject
# Out:
# ('Math', 'Biology', 'Chemistry')

# %%
# Second academic subject
first, second, last=subject
second
# Out:
# 'Biology'

# %%
subject =('Math', 'Biology', 'Chemistry','English')
subject
# Out:
# ('Math', 'Biology', 'Chemistry', 'English')

# %% [markdown]
# ##  Unique FruitsLevel: Beginner

# %%
# Creation and manipulation of Set Task
fruits= {"apple", "banana", "mango", "apple", "orange"}
print(fruits)
# Out:
# {'orange', 'apple', 'banana', 'mango'}

# %%
# Incorperating grape
fruits.add('grape')
fruits
# Out:
# {'apple', 'banana', 'grape', 'mango', 'orange'}

# %%
fruits.remove('banana')
fruits
# Out:
# {'apple', 'grape', 'mango', 'orange'}

# %%
'apple' in fruits
# Out:
# True

# %% [markdown]
# ## Set Comprehension & Filtering

# %%
# creating a set of 1-20 divisible by 3
set = {3,6,9,12,15,18}

# %%
set
# Out:
# {3, 6, 9, 12, 15, 18}

# %%
# creating another set of 1-20 divisible by 5
sets = {5,10,15,20}

# %%
sets
# Out:
# {5, 10, 15, 20}

# %%
# Determine the interaction of the two sets
set.union(sets)
# Out:
# {3, 5, 6, 9, 10, 12, 15, 18, 20}

# %%
# determine the intersectiuon of the two sets
set.intersection(sets)
# Out:
# {15}
