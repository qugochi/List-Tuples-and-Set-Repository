# %% [markdown]
# Abayomi Queen
# Set and Tuples Assignmnet
# 27/10/25

# %%
#  Accessing elements within nested tuples and employing diverse data types
student = ("Sarah", 24, ("Math", "Biology", "Chemistry"))

# %%
# Presenting students name

# %%
# Creation and manipulation of Set Task
fruits= {"apple", "banana", "mango", "apple", "orange"}
print(fruits)
# Out:
# {'banana', 'mango', 'apple', 'orange'}

# %% [raw]
# fruits.add '
